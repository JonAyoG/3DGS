# %% [markdown]
# <a href="https://colab.research.google.com/github/JonAyoG/3DGS/blob/main/gaussian_splatting_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !rm -rf gaussian-splatting
# !git clone --recursive https://github.com/camenduru/gaussian-splatting
# !pip install -q plyfile
# Out:
# /content
# Cloning into 'gaussian-splatting'...
# remote: Enumerating objects: 603, done.
# remote: Total 603 (delta 0), reused 0 (delta 0), pack-reused 603 (from 1)
# Receiving objects: 100% (603/603), 2.09 MiB | 6.54 MiB/s, done.
# Resolving deltas: 100% (344/344), done.
# Submodule 'SIBR_viewers' (https://gitlab.inria.fr/sibr/sibr_core) registered for path 'SIBR_viewers'
# Submodule 'submodules/diff-gaussian-rasterization' (https://github.com/graphdeco-inria/diff-gaussian-rasterization) registered for path 'submodules/diff-gaussian-rasterization'
# Submodule 'submodules/simple-knn' (https://gitlab.inria.fr/bkerbl/simple-knn.git) registered for path 'submodules/simple-knn'
# Cloning into '/content/gaussian-splatting/SIBR_viewers'...
# ...
# remote: Enumerating objects: 3293, done.
# remote: Counting objects: 100% (322/322), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 3293 (delta 171), reused 280 (delta 148), pack-reused 2971 (from 1)
# ...

# %%
# %cd /content/gaussian-splatting/submodules/simple-knn

# Add #include <float.h> to the top of the CUDA source file
# !sed -i '1i #include <float.h>' simple_knn.cu  || sed -i '1i #include <float.h>' simple-knn.cu

# Install in editable mode
# !pip install -q -e .
# Out:
# /content/gaussian-splatting/submodules/simple-knn
#   Preparing metadata (setup.py) ... done

# %%
# %cd /content/gaussian-splatting
# !pip install -q -e submodules/diff-gaussian-rasterization
# Out:
# /content/gaussian-splatting
#   Preparing metadata (setup.py) ... done

# %%
# %cd /content/gaussian-splatting
# !wget -q https://huggingface.co/camenduru/gaussian-splatting/resolve/main/tandt_db.zip
# !unzip -q tandt_db.zip

# !python train.py -s /content/gaussian-splatting/tandt/train
# Out:
# /content/gaussian-splatting
# 2025-11-07 10:04:44.957676: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762509884.978670   12634 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762509884.984767   12634 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1762509885.001190   12634 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %% [markdown]
# **Finding the resulting model**

# %%
# %cd /content/gaussian-splatting
# !find output -maxdepth 5 -type f -name "point_cloud.ply"
# Out:
# /content/gaussian-splatting
# output/5df11b4d-1/point_cloud/iteration_30000/point_cloud.ply
# output/5df11b4d-1/point_cloud/iteration_7000/point_cloud.ply

# %% [markdown]
# **Rendering**
#
#
# *   everything above just gives you the gaussian blobs
# *   now you have to render them to turn them into the 3D scene
